# %%
from __future__ import absolute_import, division, print_function, unicode_literals
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import keras.utils as utils
from keras.models import Sequential
import keras.layers
import numpy as np
import os

# %%
def prepareSequences(encodedLines, maxLength=None):
    sequences = list()
    for encodedLine in encodedLines:
        for i in range(1, len(encodedLine)):
            seq = encodedLine[:i + 1]
            sequences.append(seq)
    maxlen = maxLength if (maxLength) else max([len(seq) for seq in sequences])
    sequences = pad_sequences(sequences, maxlen=maxlen, padding='pre')

    # split into input and output elements
    sequences = np.array(sequences)
    x = sequences[:, :-1]
    y = sequences[:, -1]
    return x, y

def getAccuracy(predSentences, trueSentences):
    accuracy = 0
    for i in range(len(predSentences)):
        if (predSentences[i] == trueSentences[i]):
            accuracy += 1
    return accuracy / len(predSentences)

def processSentences(sentences, model, tokenizer, maxLength):
    correctedSentences = []
    vocab = tokenizer.word_index
    vocab_inv = {v: k for k, v in vocab.items()}
    for sentence in sentences:
        encoded = tokenizer.texts_to_sequences([sentence])[0]
        x, y = prepareSequences([encoded], maxLength)
        probs = model.predict(x, verbose=0)
        sentence_prob = get_sentence_prob(probs, y)
        bestEncoding = encoded
        for i, token in enumerate(encoded):
            encodedToks = tokenizer.texts_to_sequences(REMOVABLE_TOKENS)[0]
            for tok in encodedToks:
                tmpEncoded = list(encoded)
                encoded.insert(i, tok)
                tmp_x, tmp_y = prepareSequences([encoded], maxLength)
                new_probs = model.predict(tmp_x, verbose=0)
                new_sentence_prob = get_sentence_prob(new_probs, tmp_y)
                if (new_sentence_prob > sentence_prob):
                    sentence_prob = new_sentence_prob
                    bestEncoding = encoded
                encoded = tmpEncoded
        correctedSentences.append(bestEncoding)
    return correctedSentences
        # log_p_sentence = 0
        # for i, prob in enumerate(probs):
        #     word = vocab_inv[y_test[i]]
        #     history = ' '.join([vocab_inv[w] for w in x_test[i, :] if w != 0])
        #     prob_word = prob[y_test[i]]
        #     log_p_sentence += np.log(prob_word)
        #     print('P(w={} | h={})={}'.format(word, history, prob_word))
        # print('Prob. sentence: {}'.format(np.exp(log_p_sentence)))

def decodeSentence(tokens, vocab):
    return ' '.join([vocab[token] for token in tokens])

def get_sentence_prob(probs, encodedSentence):
    log_p_sentence = 0
    for i, prob in enumerate(probs):
        prob_word = prob[encodedSentence[i]]
        log_p_sentence += np.log(prob_word)
    return np.exp(log_p_sentence)

def prepareIncorrectSentences(sentences):
    return [removeToken(x) for x in sentences]

def removeToken(sentence):
    words = sentence.split(' ')
    delete_i = -1
    for i, word in enumerate(words):
        if (word in REMOVABLE_TOKENS):
            print('removing ' + word)
            delete_i = i
            break
    if (delete_i != -1):
        words.pop(delete_i)
    return ' '.join([x for x in words])

def getIncorrectSentences(sentences, num_sentences):
    x = []
    y = []
    for sent in sentences:
        new_sent = removeToken(sent)
        if (sent != new_sent):
            x.append(new_sent)
            y.append(sent)
        if (len(x) == num_sentences):
            break
    return x, y

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
NUM_SENTENCES = 1000
REMOVABLE_TOKENS = ['the', '\'ve', '\'m', '\'s', '\'d', '\'ll', '\'nt']
rawDataFile = 'C:/Users/phili/GrammarChecker/rawtext.txt'
text = open(rawDataFile, 'r').read()
sentences = text.split('\n')
trainSentences = sentences[:NUM_SENTENCES]
incorrectSentences, trueSentences = getIncorrectSentences(sentences[NUM_SENTENCES:int(NUM_SENTENCES * 2)], int(NUM_SENTENCES * 0.2))
# Out:
# removing 's
# removing the
# removing the
# removing the
# removing 's
# removing 'm
# removing 's
# removing the
# removing the
# removing the
# removing 'll
# removing the
# removing 'll
# removing 'll
# removing the
# removing 's
# removing 's
# removing 'm
# removing 's
# removing 's
# removing 'm
# removing 's
# removing 'm
# removing 's
# removing 've
# removing 's
# removing 've
# removing 've
# removing 's
# removing 'm
# removing 'm
# removing 's
# removing the
# removing 'm
# removing 's
# removing the
# removing 'm
# removing the
# removing 'm
# removing 's
# removing 'll
# removing 'd
# removing 'll
# removing the
# removing the
# removing 's
# removing the
# removing the
# removing 's
# removing the
# removing the
# removing 've
# removing 'd
# removing 'd
# removing 'm
# removing the
# removing 's
# removing the
# removing 've
# removing 's
# removing 'm
# removing 'm
# removing 's
# removing the
# removing 's
# removing 's
# removing 's
# removing 's
# removing 's
# removing 's
# removing 'm
# removing 'm
# removing 's
# removing 's
# removing the
# removing 's
# removing 's
# removing the
# removing the
# removing 'll
# removing 'm
# removing 'm
# removing the
# removing 's
# removing 'm
# removing the
# removing the
# removing the
# removing the
# removing the
# removing 'm
# removing 've
# removing 's
# removing 've
# removing 'll
# removing the
# removing 'd
# removing the
# removing the
# removing 'd
# removing 's
# removing 's
# removing 'd
# removing 'm
# removing 'll
# removing the
# removing 'll
# removing 's
# removing 'm
# removing 's
# removing 's
# removing the
# removing 'd
# removing 've
# removing 's
# removing 'd
# removing 'd
# removing the
# removing 's
# removing 'm
# removing 's
# removing 'm
# removing 's
# removing 'd
# removing 'd
# removing the
# removing 'm
# removing the
# removing the
# removing 'm
# removing 'll
# removing the
# removing 's
# removing 'm
# removing the
# removing the
# removing the
# removing 'd
# removing 'd
# removing 'd
# removing the
# removing the
# removing the
# removing 's
# removing 've
# removing 'd
# removing 'm
# removing the
# removing 'll
# removing the
# removing the
# removing the
# removing the
# removing 's
# removing the
# removing 's
# removing the
# removing the
# removing 'm
# removing the
# removing 's
# removing the
# removing the
# removing 's
# removing the
# removing 'm
# removing 'd
# removing 'd
# removing the
# removing 's
# removing 'm
# removing the
# removing 'm
# removing 's
# removing 'm
# removing the
# removing 'd
# removing 's
# removing the
# removing the
# removing the
# removing the
# removing the
# removing the
# removing 's
# removing 's
# removing the
# removing 's
# removing the
# removing 'm
# removing 'd
# removing the
# removing 'm
# removing 's
# removing the
# removing the
# removing 's
# removing 's
# removing 'm
# removing 'll

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(np.concatenate((trainSentences, trueSentences)))
trainEncoded = tokenizer.texts_to_sequences(trainSentences)
trueSentencesEncoded = tokenizer.texts_to_sequences(trueSentences)
vocab_size = len(tokenizer.word_index) + 1
print('vocab size: ' + str(vocab_size))

maxLength = max([len(x) for x in np.concatenate((trainEncoded, trueSentencesEncoded))])
x_train, y_train = prepareSequences(trainEncoded, maxLength)
x_test, y_test = prepareSequences(trueSentencesEncoded, maxLength)
y_train = utils.to_categorical(y_train, num_classes=vocab_size)
y_test = utils.to_categorical(y_test, num_classes=vocab_size)

model = Sequential()
model.add(keras.layers.Embedding(vocab_size, 10, input_length=maxLength - 1))
model.add(keras.layers.GRU(20, recurrent_dropout=0.1, dropout=0.1))
model.add(keras.layers.Dense(vocab_size, activation='softmax'))
# Out:
# vocab size: 2307

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=300, verbose=2)
loss, accuracy = model.evaluate(x_train, y_train, verbose=1)
print('training loss: ' + str(loss) + ', accuracy: ' + str(accuracy))
loss, accuracy = model.evaluate(x_test, y_test, verbose=1)
print('test loss: ' + str(loss) + ', accuracy: ' + str(accuracy))
# Out:
# c:\users\phili\grammarchecker\env\lib\site-packages\tensorflow_core\python\framework\indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/300
#  - 36s - loss: 6.7674 - accuracy: 0.0365
# Epoch 2/300
#  - 35s - loss: 6.1682 - accuracy: 0.0350
# Epoch 3/300
#  - 35s - loss: 6.0951 - accuracy: 0.0356
# Epoch 4/300
#  - 35s - loss: 6.0277 - accuracy: 0.0378
# Epoch 5/300
#  - 35s - loss: 5.9643 - accuracy: 0.0389
# Epoch 6/300
#  - 35s - loss: 5.9072 - accuracy: 0.0446
# Epoch 7/300
#  - 35s - loss: 5.8603 - accuracy: 0.0445
# Epoch 8/300
#  - 35s - loss: 5.8125 - accuracy: 0.0474
# Epoch 9/300
#  - 35s - loss: 5.7675 - accuracy: 0.0481
# Epoch 10/300
#  - 35s - loss: 5.7214 - accuracy: 0.0575
# Epoch 11/300
#  - 35s - loss: 5.6730 - accuracy: 0.0603
# Epoch 12/300
#  - 35s - loss: 5.6243 - accuracy: 0.0620
# Epoch 13/300
#  - 35s - loss: 5.5753 - accuracy: 0.0627
# Epoch 14/300
#  - 35s - loss: 5.5216 - accuracy: 0.0632
# Epoch 15/300
#  - 35s - loss: 5.4663 - accuracy: 0.0671
# Epoch 16/300
#  - 35s - loss: 5.4132 - accuracy: 0.0720
# Epoch 17/300
#  - 35s - loss: 5.3567 - accuracy: 0.0795
# Epoch 18/300
#  - 35s - loss: 5.3022 - accuracy: 0.0834
# Epoch 19/300
#  - 35s - loss: 5.2491 - accuracy: 0.0912
# Epoch 20/300
#  - 35s - loss: 5.1991 - accuracy: 0.0935
# Epoch 21/300
#  - 35s - loss: 5.1579 - accuracy: 0.0964
# Epoch 22/300
#  - 35s - loss: 5.1123 - accuracy: 0.1021
# Epoch 23/300
#  - 36s - loss: 5.0678 - accuracy: 0.1074
# Epoch 24/300
#  - 35s - loss: 5.0316 - accuracy: 0.1096
# Epoch 25/300
#  - 35s - loss: 4.9833 - accuracy: 0.1176
# Epoch 26/300
#  - 35s - loss: 4.9505 - accuracy: 0.1183
# Epoch 27/300
#  - 36s - loss: 4.9108 - accuracy: 0.1225
# Epoch 28/300
#  - 35s - loss: 4.8784 - accuracy: 0.1266
# Epoch 29/300
#  - 36s - loss: 4.8477 - accuracy: 0.1259
# Epoch 30/300
#  - 35s - loss: 4.8159 - accuracy: 0.1301
# Epoch 31/300
#  - 36s - loss: 4.7813 - accuracy: 0.1331
# Epoch 32/300
#  - 35s - loss: 4.7525 - accuracy: 0.1361
# Epoch 33/300
#  - 35s - loss: 4.7152 - accuracy: 0.1409
# Epoch 34/300
#  - 35s - loss: 4.6985 - accuracy: 0.1390
# Epoch 35/300
#  - 36s - loss: 4.6695 - accuracy: 0.1423
# Epoch 36/300
#  - 35s - loss: 4.6392 - accuracy: 0.1460
# Epoch 37/300
#  - 35s - loss: 4.6150 - accuracy: 0.1447
# Epoch 38/300
#  - 35s - loss: 4.5878 - accuracy: 0.1471
# Epoch 39/300
#  - 35s - loss: 4.5647 - accuracy: 0.1529
# Epoch 40/300
#  - 35s - loss: 4.5465 - accuracy: 0.1488
# Epoch 41/300
#  - 35s - loss: 4.5180 - accuracy: 0.1540
# Epoch 42/300
#  - 35s - loss: 4.5707 - accuracy: 0.1527
# Epoch 43/300
#  - 35s - loss: 4.4746 - accuracy: 0.1597
# Epoch 44/300
#  - 35s - loss: 4.4529 - accuracy: 0.1551
# Epoch 45/300
#  - 35s - loss: 4.4357 - accuracy: 0.1618
# Epoch 46/300
#  - 35s - loss: 4.4256 - accuracy: 0.1584
# Epoch 47/300
#  - 35s - loss: 4.3955 - accuracy: 0.1633
# Epoch 48/300
#  - 36s - loss: 4.3772 - accuracy: 0.1611
# Epoch 49/300
#  - 35s - loss: 4.3628 - accuracy: 0.1659
# Epoch 50/300
#  - 36s - loss: 4.3411 - accuracy: 0.1646
# Epoch 51/300
#  - 36s - loss: 4.3245 - accuracy: 0.1679
# Epoch 52/300
#  - 35s - loss: 4.3137 - accuracy: 0.1669
# Epoch 53/300
#  - 36s - loss: 4.2873 - accuracy: 0.1691
# Epoch 54/300
#  - 35s - loss: 4.2790 - accuracy: 0.1667
# Epoch 55/300
#  - 36s - loss: 4.4068 - accuracy: 0.1713
# Epoch 56/300
#  - 36s - loss: 4.2421 - accuracy: 0.1728
# Epoch 57/300
#  - 35s - loss: 4.3685 - accuracy: 0.1760
# Epoch 58/300
#  - 35s - loss: 4.2102 - accuracy: 0.1778
# Epoch 59/300
#  - 35s - loss: 4.2026 - accuracy: 0.1787
# Epoch 60/300
#  - 35s - loss: 4.1812 - accuracy: 0.1788
# Epoch 61/300
#  - 35s - loss: 4.1678 - accuracy: 0.1791
# Epoch 62/300
#  - 35s - loss: 4.1549 - accuracy: 0.1824
# Epoch 63/300
#  - 36s - loss: 4.1399 - accuracy: 0.1841
# Epoch 64/300
#  - 35s - loss: 4.1187 - accuracy: 0.1887
# Epoch 65/300
#  - 35s - loss: 4.1134 - accuracy: 0.1854
# Epoch 66/300
#  - 35s - loss: 4.0969 - accuracy: 0.1828
# Epoch 67/300
#  - 36s - loss: 4.0814 - accuracy: 0.1885
# Epoch 68/300
#  - 36s - loss: 4.0787 - accuracy: 0.1921
# Epoch 69/300
#  - 35s - loss: 4.0537 - accuracy: 0.1908
# Epoch 70/300
#  - 36s - loss: 4.0410 - accuracy: 0.1946
# Epoch 71/300
#  - 35s - loss: 4.1057 - accuracy: 0.1973
# Epoch 72/300
#  - 35s - loss: 4.0223 - accuracy: 0.1964
# Epoch 73/300
#  - 35s - loss: 4.0000 - accuracy: 0.1933
# Epoch 74/300
#  - 36s - loss: 3.9944 - accuracy: 0.1972
# Epoch 75/300
#  - 36s - loss: 3.9770 - accuracy: 0.1981
# Epoch 76/300
#  - 36s - loss: 3.9813 - accuracy: 0.1967
# Epoch 77/300
#  - 35s - loss: 3.9598 - accuracy: 0.1996
# Epoch 78/300
#  - 35s - loss: 3.9492 - accuracy: 0.2017
# Epoch 79/300
#  - 36s - loss: 3.9403 - accuracy: 0.2023
# Epoch 80/300
#  - 36s - loss: 3.9770 - accuracy: 0.2028
# Epoch 81/300
#  - 35s - loss: 3.9251 - accuracy: 0.2050
# Epoch 82/300
#  - 36s - loss: 3.9011 - accuracy: 0.2085
# Epoch 83/300
#  - 36s - loss: 3.8946 - accuracy: 0.2063
# Epoch 84/300
#  - 35s - loss: 3.8922 - accuracy: 0.2095
# Epoch 85/300
#  - 36s - loss: 3.9086 - accuracy: 0.2118
# Epoch 86/300
#  - 36s - loss: 3.8656 - accuracy: 0.2117
# Epoch 87/300
#  - 35s - loss: 3.8506 - accuracy: 0.2154
# Epoch 88/300
#  - 36s - loss: 3.8552 - accuracy: 0.2131
# Epoch 89/300
#  - 36s - loss: 4.1763 - accuracy: 0.2163
# Epoch 90/300
#  - 36s - loss: 3.8387 - accuracy: 0.2155
# Epoch 91/300
#  - 34s - loss: 3.8268 - accuracy: 0.2202
# Epoch 92/300
#  - 35s - loss: 3.8112 - accuracy: 0.2231
# Epoch 93/300
#  - 35s - loss: 3.7929 - accuracy: 0.2214
# Epoch 94/300
#  - 35s - loss: 3.7941 - accuracy: 0.2238
# Epoch 95/300
#  - 36s - loss: 3.7908 - accuracy: 0.2222
# Epoch 96/300
#  - 35s - loss: 3.7628 - accuracy: 0.2260
# Epoch 97/300
#  - 35s - loss: 3.7761 - accuracy: 0.2278
# Epoch 98/300
#  - 36s - loss: 3.7617 - accuracy: 0.2241
# Epoch 99/300
#  - 35s - loss: 3.7485 - accuracy: 0.2257
# Epoch 100/300
#  - 35s - loss: 3.7361 - accuracy: 0.2296
# Epoch 101/300
#  - 35s - loss: 3.7344 - accuracy: 0.2240
# Epoch 102/300
#  - 35s - loss: 3.7305 - accuracy: 0.2315
# Epoch 103/300
#  - 36s - loss: 3.7126 - accuracy: 0.2331
# Epoch 104/300
#  - 35s - loss: 3.7103 - accuracy: 0.2324
# Epoch 105/300
#  - 36s - loss: 3.7088 - accuracy: 0.2320
# Epoch 106/300
#  - 36s - loss: 3.6868 - accuracy: 0.2379
# Epoch 107/300
#  - 35s - loss: 3.6863 - accuracy: 0.2371
# Epoch 108/300
#  - 34s - loss: 3.6849 - accuracy: 0.2342
# Epoch 109/300
#  - 31s - loss: 3.6671 - accuracy: 0.2413
# Epoch 110/300
#  - 31s - loss: 3.6682 - accuracy: 0.2384
# Epoch 111/300
#  - 31s - loss: 3.6576 - accuracy: 0.2442
# Epoch 112/300
#  - 31s - loss: 3.6522 - accuracy: 0.2408
# Epoch 113/300
#  - 31s - loss: 3.6429 - accuracy: 0.2425
# Epoch 114/300
#  - 31s - loss: 3.6316 - accuracy: 0.2421
# Epoch 115/300
#  - 31s - loss: 3.6297 - accuracy: 0.2463
# Epoch 116/300
#  - 31s - loss: 3.6129 - accuracy: 0.2462
# Epoch 117/300
#  - 31s - loss: 3.6202 - accuracy: 0.2432
# Epoch 118/300
#  - 30s - loss: 3.6053 - accuracy: 0.2473
# Epoch 119/300
#  - 30s - loss: 3.5965 - accuracy: 0.2482
# Epoch 120/300
#  - 30s - loss: 3.5798 - accuracy: 0.2496
# Epoch 121/300
#  - 31s - loss: 3.6009 - accuracy: 0.2496
# Epoch 122/300
#  - 31s - loss: 3.5685 - accuracy: 0.2526
# Epoch 123/300
#  - 31s - loss: 3.6157 - accuracy: 0.2489
# Epoch 124/300
#  - 31s - loss: 3.5832 - accuracy: 0.2516
# Epoch 125/300
#  - 31s - loss: 3.5718 - accuracy: 0.2503
# Epoch 126/300
#  - 31s - loss: 3.5525 - accuracy: 0.2581
# Epoch 127/300
#  - 31s - loss: 3.5514 - accuracy: 0.2542
# Epoch 128/300
#  - 31s - loss: 3.5395 - accuracy: 0.2545
# Epoch 129/300
#  - 31s - loss: 3.5341 - accuracy: 0.2580
# Epoch 130/300
#  - 30s - loss: 3.5196 - accuracy: 0.2584
# Epoch 131/300
#  - 31s - loss: 3.5243 - accuracy: 0.2561
# Epoch 132/300
#  - 31s - loss: 3.5245 - accuracy: 0.2563
# Epoch 133/300
#  - 32s - loss: 3.5320 - accuracy: 0.2585
# Epoch 134/300
#  - 31s - loss: 3.5063 - accuracy: 0.2582
# Epoch 135/300
#  - 31s - loss: 3.5105 - accuracy: 0.2580
# Epoch 136/300
#  - 31s - loss: 3.4968 - accuracy: 0.2655
# Epoch 137/300
#  - 31s - loss: 3.4827 - accuracy: 0.2667
# Epoch 138/300
#  - 30s - loss: 3.4906 - accuracy: 0.2650
# Epoch 139/300
#  - 30s - loss: 3.4628 - accuracy: 0.2690
# Epoch 140/300
#  - 31s - loss: 3.4593 - accuracy: 0.2659
# Epoch 141/300
#  - 30s - loss: 3.4744 - accuracy: 0.2662
# Epoch 142/300
#  - 31s - loss: 3.4589 - accuracy: 0.2601
# Epoch 143/300
#  - 31s - loss: 3.4724 - accuracy: 0.2653
# Epoch 144/300
#  - 30s - loss: 3.4449 - accuracy: 0.2682
# Epoch 145/300
#  - 30s - loss: 3.4612 - accuracy: 0.2696
# Epoch 146/300
#  - 31s - loss: 3.4363 - accuracy: 0.2698
# Epoch 147/300
#  - 30s - loss: 3.4437 - accuracy: 0.2688
# Epoch 148/300
#  - 31s - loss: 3.4320 - accuracy: 0.2690
# Epoch 149/300
#  - 30s - loss: 3.4314 - accuracy: 0.2691
# Epoch 150/300
#  - 31s - loss: 3.4266 - accuracy: 0.2787
# Epoch 151/300
#  - 30s - loss: 3.4288 - accuracy: 0.2724
# Epoch 152/300
#  - 31s - loss: 3.4226 - accuracy: 0.2687
# Epoch 153/300
#  - 30s - loss: 3.4119 - accuracy: 0.2683
# Epoch 154/300
#  - 30s - loss: 3.4064 - accuracy: 0.2772
# Epoch 155/300
#  - 31s - loss: 3.3920 - accuracy: 0.2742
# Epoch 156/300
#  - 30s - loss: 3.3905 - accuracy: 0.2789
# Epoch 157/300
#  - 31s - loss: 3.4018 - accuracy: 0.2770
# Epoch 158/300
#  - 30s - loss: 3.3954 - accuracy: 0.2733
# Epoch 159/300
#  - 30s - loss: 3.3736 - accuracy: 0.2799
# Epoch 160/300
#  - 31s - loss: 3.3844 - accuracy: 0.2778
# Epoch 161/300
#  - 31s - loss: 3.3740 - accuracy: 0.2784
# Epoch 162/300
#  - 31s - loss: 3.3646 - accuracy: 0.2799
# Epoch 163/300
#  - 31s - loss: 3.3749 - accuracy: 0.2788
# Epoch 164/300
#  - 30s - loss: 3.3596 - accuracy: 0.2832
# Epoch 165/300
#  - 31s - loss: 3.3641 - accuracy: 0.2787
# Epoch 166/300
#  - 30s - loss: 3.3570 - accuracy: 0.2827
# Epoch 167/300
#  - 31s - loss: 3.3462 - accuracy: 0.2817
# Epoch 168/300
#  - 30s - loss: 3.3610 - accuracy: 0.2842
# Epoch 169/300
#  - 31s - loss: 3.3514 - accuracy: 0.2808
# Epoch 170/300
#  - 30s - loss: 3.3352 - accuracy: 0.2840
# Epoch 171/300
#  - 31s - loss: 3.3284 - accuracy: 0.2826
# Epoch 172/300
#  - 31s - loss: 3.3316 - accuracy: 0.2833
# Epoch 173/300
#  - 31s - loss: 3.3359 - accuracy: 0.2899
# Epoch 174/300
#  - 31s - loss: 3.3231 - accuracy: 0.2848
# Epoch 175/300
#  - 31s - loss: 3.3202 - accuracy: 0.2871
# Epoch 176/300
#  - 31s - loss: 3.3866 - accuracy: 0.2857
# Epoch 177/300
#  - 30s - loss: 3.3306 - accuracy: 0.2901
# Epoch 178/300
#  - 31s - loss: 3.3080 - accuracy: 0.2857
# Epoch 179/300
#  - 30s - loss: 3.3146 - accuracy: 0.2820
# Epoch 180/300
#  - 30s - loss: 3.3041 - accuracy: 0.2879
# Epoch 181/300
#  - 31s - loss: 3.4027 - accuracy: 0.2911
# Epoch 182/300
#  - 31s - loss: 3.2900 - accuracy: 0.2899
# Epoch 183/300
#  - 31s - loss: 3.2995 - accuracy: 0.2863
# Epoch 184/300
#  - 31s - loss: 3.2865 - accuracy: 0.2927
# Epoch 185/300
#  - 31s - loss: 3.2892 - accuracy: 0.2951
# Epoch 186/300
#  - 31s - loss: 3.2849 - accuracy: 0.2919
# Epoch 187/300
#  - 31s - loss: 3.2736 - accuracy: 0.2964
# Epoch 188/300
#  - 31s - loss: 3.2699 - accuracy: 0.2933
# Epoch 189/300
#  - 30s - loss: 3.2793 - accuracy: 0.2946
# Epoch 190/300
#  - 31s - loss: 3.2911 - accuracy: 0.2939
# Epoch 191/300
#  - 31s - loss: 3.2660 - accuracy: 0.2923
# Epoch 192/300
#  - 31s - loss: 3.2651 - accuracy: 0.3005
# Epoch 193/300
#  - 30s - loss: 3.2674 - accuracy: 0.2971
# Epoch 194/300
#  - 30s - loss: 3.2394 - accuracy: 0.3005
# Epoch 195/300
#  - 30s - loss: 3.2537 - accuracy: 0.2985
# Epoch 196/300
#  - 31s - loss: 3.2565 - accuracy: 0.2984
# Epoch 197/300
#  - 30s - loss: 3.2482 - accuracy: 0.2931
# Epoch 198/300
#  - 31s - loss: 3.2514 - accuracy: 0.2931
# Epoch 199/300
#  - 30s - loss: 3.2491 - accuracy: 0.2932
# Epoch 200/300
#  - 31s - loss: 3.2349 - accuracy: 0.2962
# Epoch 201/300
#  - 30s - loss: 3.2424 - accuracy: 0.2959
# Epoch 202/300
#  - 31s - loss: 3.2287 - accuracy: 0.3010
# Epoch 203/300
#  - 31s - loss: 3.4000 - accuracy: 0.2968
# Epoch 204/300
#  - 30s - loss: 3.2371 - accuracy: 0.2986
# Epoch 205/300
#  - 31s - loss: 3.2340 - accuracy: 0.3008
# Epoch 206/300
#  - 30s - loss: 3.2215 - accuracy: 0.2991
# Epoch 207/300
#  - 30s - loss: 3.2242 - accuracy: 0.3027
# Epoch 208/300
#  - 31s - loss: 3.2138 - accuracy: 0.2987
# Epoch 209/300
#  - 30s - loss: 3.2178 - accuracy: 0.3020
# Epoch 210/300
#  - 30s - loss: 3.2123 - accuracy: 0.3021
# Epoch 211/300
#  - 31s - loss: 3.2309 - accuracy: 0.3046
# Epoch 212/300
#  - 30s - loss: 3.1969 - accuracy: 0.3097
# Epoch 213/300
#  - 31s - loss: 3.2133 - accuracy: 0.3028
# Epoch 214/300
#  - 32s - loss: 3.1995 - accuracy: 0.3040
# Epoch 215/300
#  - 30s - loss: 3.2288 - accuracy: 0.3046
# Epoch 216/300
#  - 31s - loss: 3.1992 - accuracy: 0.3068
# Epoch 217/300
#  - 30s - loss: 3.1844 - accuracy: 0.3096
# Epoch 218/300
#  - 31s - loss: 3.2061 - accuracy: 0.3058
# Epoch 219/300
#  - 31s - loss: 3.1912 - accuracy: 0.3057
# Epoch 220/300
#  - 31s - loss: 3.1928 - accuracy: 0.3026
# Epoch 221/300
#  - 31s - loss: 3.1944 - accuracy: 0.3055
# Epoch 222/300
#  - 31s - loss: 3.1864 - accuracy: 0.3045
# Epoch 223/300
#  - 30s - loss: 3.1906 - accuracy: 0.3069
# Epoch 224/300
#  - 30s - loss: 3.1807 - accuracy: 0.3063
# Epoch 225/300
#  - 31s - loss: 3.1818 - accuracy: 0.3099
# Epoch 226/300
#  - 30s - loss: 3.2233 - accuracy: 0.3050
# Epoch 227/300
#  - 30s - loss: 3.1974 - accuracy: 0.3042
# Epoch 228/300
#  - 31s - loss: 3.1701 - accuracy: 0.3088
# Epoch 229/300
#  - 30s - loss: 3.1697 - accuracy: 0.3043
# Epoch 230/300
#  - 31s - loss: 3.1575 - accuracy: 0.3117
# Epoch 231/300
#  - 31s - loss: 3.1737 - accuracy: 0.3056
# Epoch 232/300
#  - 31s - loss: 3.1569 - accuracy: 0.3101
# Epoch 233/300
#  - 31s - loss: 3.1501 - accuracy: 0.3099
# Epoch 234/300
#  - 30s - loss: 3.1617 - accuracy: 0.3102
# Epoch 235/300
#  - 30s - loss: 3.1427 - accuracy: 0.3099
# Epoch 236/300
#  - 31s - loss: 3.7524 - accuracy: 0.3117
# Epoch 237/300
#  - 31s - loss: 3.1700 - accuracy: 0.3070
# Epoch 238/300
#  - 31s - loss: 3.1702 - accuracy: 0.3105
# Epoch 239/300
#  - 31s - loss: 3.1878 - accuracy: 0.3082
# Epoch 240/300
#  - 30s - loss: 3.1557 - accuracy: 0.3125
# Epoch 241/300
#  - 31s - loss: 3.1247 - accuracy: 0.3197
# Epoch 242/300
#  - 30s - loss: 3.1295 - accuracy: 0.3172
# Epoch 243/300
#  - 31s - loss: 3.1382 - accuracy: 0.3116
# Epoch 244/300
#  - 31s - loss: 3.1424 - accuracy: 0.3157
# Epoch 245/300
#  - 31s - loss: 3.1491 - accuracy: 0.3083
# Epoch 246/300
#  - 31s - loss: 3.1207 - accuracy: 0.3180
# Epoch 247/300
#  - 31s - loss: 3.1283 - accuracy: 0.3150
# Epoch 248/300
#  - 31s - loss: 3.1250 - accuracy: 0.3097
# Epoch 249/300
#  - 31s - loss: 3.1280 - accuracy: 0.3137
# Epoch 250/300
#  - 32s - loss: 3.1313 - accuracy: 0.3185
# Epoch 251/300
#  - 30s - loss: 3.1350 - accuracy: 0.3186
# Epoch 252/300
#  - 31s - loss: 3.1172 - accuracy: 0.3175
# Epoch 253/300
#  - 30s - loss: 3.1046 - accuracy: 0.3172
# Epoch 254/300
#  - 31s - loss: 3.1090 - accuracy: 0.3186
# Epoch 255/300
#  - 31s - loss: 3.1048 - accuracy: 0.3166
# Epoch 256/300
#  - 31s - loss: 3.1150 - accuracy: 0.3162
# Epoch 257/300
#  - 31s - loss: 3.0991 - accuracy: 0.3185
# Epoch 258/300
#  - 30s - loss: 3.1208 - accuracy: 0.3144
# Epoch 259/300
#  - 30s - loss: 3.1068 - accuracy: 0.3188
# Epoch 260/300
#  - 31s - loss: 3.1185 - accuracy: 0.3163
# Epoch 261/300
#  - 30s - loss: 3.1089 - accuracy: 0.3185
# Epoch 262/300
#  - 30s - loss: 3.0921 - accuracy: 0.3224
# Epoch 263/300
#  - 31s - loss: 3.1010 - accuracy: 0.3126
# Epoch 264/300
#  - 31s - loss: 3.1163 - accuracy: 0.3158
# Epoch 265/300
#  - 31s - loss: 3.0800 - accuracy: 0.3209
# Epoch 266/300
#  - 30s - loss: 3.0876 - accuracy: 0.3210
# Epoch 267/300
#  - 31s - loss: 3.0970 - accuracy: 0.3197
# Epoch 268/300
#  - 31s - loss: 3.0969 - accuracy: 0.3191
# Epoch 269/300
#  - 31s - loss: 3.0771 - accuracy: 0.3222
# Epoch 270/300
#  - 31s - loss: 3.0822 - accuracy: 0.3188
# Epoch 271/300
#  - 31s - loss: 3.0945 - accuracy: 0.3178
# Epoch 272/300
#  - 31s - loss: 3.0760 - accuracy: 0.3215
# Epoch 273/300
#  - 31s - loss: 3.0896 - accuracy: 0.3236
# Epoch 274/300
#  - 31s - loss: 3.1122 - accuracy: 0.3158
# Epoch 275/300
#  - 31s - loss: 3.0666 - accuracy: 0.3218
# Epoch 276/300
#  - 31s - loss: 3.0747 - accuracy: 0.3235
# Epoch 277/300
#  - 30s - loss: 3.0702 - accuracy: 0.3202
# Epoch 278/300
#  - 31s - loss: 3.0746 - accuracy: 0.3241
# Epoch 279/300
#  - 31s - loss: 3.0688 - accuracy: 0.3240
# Epoch 280/300
#  - 31s - loss: 3.0677 - accuracy: 0.3232
# Epoch 281/300
#  - 31s - loss: 3.0742 - accuracy: 0.3189
# Epoch 282/300
#  - 30s - loss: 3.0719 - accuracy: 0.3190
# Epoch 283/300
#  - 31s - loss: 3.0629 - accuracy: 0.3250
# Epoch 284/300
#  - 31s - loss: 3.0773 - accuracy: 0.3243
# Epoch 285/300
#  - 30s - loss: 3.5356 - accuracy: 0.3263
# Epoch 286/300
#  - 31s - loss: 3.0608 - accuracy: 0.3237
# Epoch 287/300
#  - 31s - loss: 3.0596 - accuracy: 0.3229
# Epoch 288/300
#  - 31s - loss: 3.0547 - accuracy: 0.3236
# Epoch 289/300
#  - 31s - loss: 3.0560 - accuracy: 0.3237
# Epoch 290/300
#  - 31s - loss: 3.0535 - accuracy: 0.3244
# Epoch 291/300
#  - 31s - loss: 3.0532 - accuracy: 0.3246
# Epoch 292/300
#  - 30s - loss: 3.0529 - accuracy: 0.3187
# Epoch 293/300
#  - 31s - loss: 3.0468 - accuracy: 0.3290
# Epoch 294/300
#  - 31s - loss: 3.0450 - accuracy: 0.3254
# Epoch 295/300
#  - 31s - loss: 3.0254 - accuracy: 0.3285
# Epoch 296/300
#  - 31s - loss: 3.0399 - accuracy: 0.3255
# Epoch 297/300
#  - 31s - loss: 3.0458 - accuracy: 0.3259
# Epoch 298/300
#  - 31s - loss: 3.0245 - accuracy: 0.3307
# Epoch 299/300
#  - 31s - loss: 3.0399 - accuracy: 0.3285
# Epoch 300/300
#  - 31s - loss: 3.0225 - accuracy: 0.3291
# 9714/9714 [==============================] - 14s 1ms/step
# training loss: 3.011261841139971, accuracy: 0.3491867482662201
# 2206/2206 [==============================] - 3s 1ms/step
# test loss: 8.52145636308658, accuracy: 0.12420670688152313

# %%
# incorrectSentences, trueSentences = getIncorrectSentences(sentences[NUM_SENTENCES:int(NUM_SENTENCES * 2)], int(NUM_SENTENCES * 0.2))
# trueSentencesEncoded = tokenizer.texts_to_sequences(trueSentences)
incorrectSentences, trueSentences = getIncorrectSentences(['it \'s that hot rod joey , right ? that \'s who you want me to bend my rules for ?'], 1)
trueSentencesEncoded = tokenizer.texts_to_sequences(trueSentences)
correctedSentences = processSentences(incorrectSentences, model, tokenizer, maxLength)

vocab = tokenizer.word_index
vocab_inv = {v: k for k, v in vocab.items()}

for i in range(len(correctedSentences)):
    print('orig: ' + incorrectSentences[i])
    print('pred: ' + decodeSentence(correctedSentences[i], vocab_inv))
    print('true: ' + decodeSentence(trueSentencesEncoded[i], vocab_inv))


# print(getAccuracy(correctedSentences, tokenizer.texts_to_sequences(['he \'ll never get it right . try the log ride !'])))
print(getAccuracy(correctedSentences, trueSentencesEncoded))
# Out:
# removing 's
# orig: it that hot rod joey , right ? that 's who you want me to bend my rules for ?
# pred: it that the hot rod joey right that 's who you want me to bend my rules for
# true: it 's that hot rod joey right that 's who you want me to bend my rules for
# 0.0

# %%
# evaluate
testText = 'it \'s that hot rod joey , right ? that \'s who you want me to bend my rules for ?'
testEncoded = tokenizer.texts_to_sequences(testText.split('\n'))
x_test, y_test = prepareSequences(testEncoded, maxLength)
probabilities = model.predict(x_test, verbose=0)

vocab = tokenizer.word_index
vocab_inv = {v: k for k, v in vocab.items()}
log_p_sentence = 0
for i, prob in enumerate(probabilities):
    word = vocab_inv[y_test[i]]  # Index 0 from vocab is reserved to <PAD>
    history = ' '.join([vocab_inv[w] for w in x_test[i, :] if w != 0])
    prob_word = prob[y_test[i]]
    log_p_sentence += np.log(prob_word)
    print('P(w={}|h={})={}'.format(word, history, prob_word))
print('Prob. sentence: {}'.format(np.exp(log_p_sentence)))
# Out:
# P(w='s|h=it)=0.4375620484352112
# P(w=that|h=it 's)=0.010767229832708836
# P(w=hot|h=it 's that)=1.9072000156938884e-07
# P(w=rod|h=it 's that hot)=2.3153397601949344e-11
# P(w=joey|h=it 's that hot rod)=2.749241390098689e-10
# P(w=right|h=it 's that hot rod joey)=5.533802323043346e-07
# P(w=that|h=it 's that hot rod joey right)=0.018543928861618042
# P(w='s|h=it 's that hot rod joey right that)=0.08000627905130386
# P(w=who|h=it 's that hot rod joey right that 's)=4.960089086125663e-07
# P(w=you|h=it 's that hot rod joey right that 's who)=0.001036177622154355
# P(w=want|h=it 's that hot rod joey right that 's who you)=0.02686837688088417
# P(w=me|h=it 's that hot rod joey right that 's who you want)=0.008253298699855804
# P(w=to|h=it 's that hot rod joey right that 's who you want me)=0.46150097250938416
# P(w=bend|h=it 's that hot rod joey right that 's who you want me to)=2.244991519073647e-11
# P(w=my|h=it 's that hot rod joey right that 's who you want me to bend)=0.0015792143531143665
# P(w=rules|h=it 's that hot rod joey right that 's who you want me to bend my)=6.835291221918283e-10
# P(w=for|h=it 's that hot rod joey right that 's who you want me to bend my rules)=0.0027596536092460155
# Prob. sentence: 1.651767714803103e-77

# %%
# 'console' with 'the': .35111
# 'console' without 'the': .04584
